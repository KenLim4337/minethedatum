# %%
#Add event_classification field to click stream logs

from pymongo import MongoClient
from pymongo.errors import BulkWriteError
import json

client = MongoClient()
dbname = 'DataMiningProject'
db = client[dbname]
"""
Support Code Prodived by UQx

Classifies event in function of their description. 
Cleans up some of the event data and makes it more human readable.
""" 
def event_classification(event):
    classification = "None"
 
    feature_eventmap_dict = {'forumread': '/discussion/forum/', 'forumcommentread': '/discussion/comments/',
                             'videoplay': 'play_video', 'videopause': 'pause_video', 'videostop': 'stop_video', 
                             'videoseek': 'seek_video', 'videospeedchange': 'speed_change_video',
                             'forumsearch': 'discussion/forum/search', 'checkprogress': 'progress',
                             'videoload': 'load_video'
                            }
    #Loop over the feature to event map and classify the event in function of the value it contains
    for key in feature_eventmap_dict:
        if  feature_eventmap_dict[key] in event:
            classification = key
            break;
    
    return classification

"""
Support Code provided by UQx

Processes the clicks stream i.e:
Initial data clean up.
Adds a classification field to events in the clickstream.
"""
def process_clickstream(db):
    # Find all forum posts
    cursor = db.clickstream.find()
    
    bulk_op = db.clickstream.initialize_unordered_bulk_op()
    cnt = 1
    for document in cursor:
        #print document
        mongo_id = document['_id']
        
        event_type = document['event_type']
        
        event = document['event'] # this returns a string
        
        #Retrieve classifcation for the event
        classification = event_classification(event_type)
        #Initialise count variable 
        cnt = 1
        #Dealing  with some more precise classification cases 
        
        #if a forum search was executed
        if 'discussion/forum/search' in event_type:
            if cnt < 10:
                #print document['event']
                cnt += 1
            #Retrieve JSON object
            event_dict = json.loads(event)
            searchtext = ""
            #The user sorted answers on the forum
            if "sort_key" in event_dict['GET']:
                classification = "forumsort"
                
            #The user searched on the forum
            elif "text" in event_dict['GET']:
                classification = "forumsearch"
                searchtext = event_dict['GET']['text']
                #print searchtext
            #Update all
            bulk_op.find({'_id': mongo_id}).update({'$set': {'event_classification': classification, 'searchtext': searchtext}})
      
      #if a video was viewed/loaded give the update the event id with the id in the clickstream 
        elif event_type in ['play_video','load_video']:
            #print event
            event_dict = json.loads(event)
            bulk_op.find({'_id': mongo_id}).update({'$set': {'event_classification': classification, 'event_id': event_dict['id']}})
        else:
            #General case add the classification to the event
            bulk_op.find({'_id': mongo_id}).update({'$set': {'event_classification': classification}})
        
    try:
        bulk_op.execute()
    except BulkWriteError as bwe:
        print bwe.details
        
        
def test():
    
    #pipeline = [ 
    #{ "$match": { "event_classification": "videoplay", "context.user_id": 2660628}  },
    #{ "$group": { "_id": "$event.id"}, {"count": { "$sum": 1 }}   },
    #{ "$group": { "_id": 1, "count": { "$sum": 1 } } }
    #]
 
    #pipeline = [ 
    #{ "$match": { "event_classification": "videoplay", "context.user_id": 2660628}},
    #{ "$group": {
    #    "_id": "$event.id",
    #    "distinctCount": { "$sum": 1 }
    #}}
    #]
    
    pipeline = [
        { "$match": { "event_classification": "videoplay", "context.user_id": 2660628}},
        { "$group": { "_id": "$event_id"}  },{ "$group": { "_id": 1, "count": { "$sum": 1 } } } 
    ]

    docs = db.clickstream.aggregate(pipeline)
    
    docs = db.clickstream.distinct("event_id", { "event_classification": "videoplay", "context.user_id": 2660628})
    print len(docs)
    
    #for doc in docs:
    #    print doc
    
    results_count = db.clickstream.find({"event_classification": "videoplay", "context.user_id": 2660628}).count()
    print results_count

# %%
process_clickstream(db)
#test()
# Out:
# [u'statistical']
# [u'quiz']
# [u'parkinson2012']
# [u'planed and organised']
# [u'']
# [u'Nancy']
# [u'show answer']
# [u'brett']
# [u'tunic']
# [u'When is next lesson?']
# [u'brett']
# [u'tunic']
# [u'verified']
# [u'photo discrepancies']
# [u'Hilary']
# [u'clues']
# [u'']
# [u'ltc73']
# [u'Nancy']
# [u'']
# [u'did we ever get a gender on the clothing']
# [u'mark moore']
# [u'translate']
# [u'planed and organised']
# [u'iadnanllb']
# [u'planed and ']
# [u'certificate']
# [u'episode 1 - profiling']
# [u'certificate']
# [u'grading']
# [u'progress']
# [u'andyduggan']
# [u'backpack']
# [u'progress']
# [u'progress']
# [u'music']
# [u'beggar']
# [u'Early questions... risky answers']
# [u'progress']
# [u'progress']
# [u'progress bar']
# [u'expressive']
# [u'celey']
# [u'pkchabot']
# [u'edit a post']
# [u'profesional']
# [u'bag']
# [u'tunic']
# [u'brett']
# [u'by anonymous']
# [u'anonymous']
# [u'ildin']
# [u'celestelawson']
# [u'progress']
# [u'interviewing']
# [u'episode 2 topic']
# [u'']
# [u'cross cultural studies']
# [u'video']
# [u'transcript']
# [u'The right technique']
# [u'woman']
# [u'Man']
# [u'BRiKie']
# [u'male ']
# [u'Man or Woman?']
# [u'BriKie']
# [u'BriKie']
# [u'celey']
# [u'tunic']
# [u'tv crime']
# [u'zan']
# [u'brett']
# [u'russ\u0131an']
# [u'surprised']
# [u'left handed']
# [u'think101']
# [u'BriKie']
# [u'negi']
# [u'negi_dee']
# [u'tv']
# [u'gws001']
# [u'baigman']
# [u'celey']
# [u'mixed']
# [u'kpmenon']
# [u'negi_dee']
# [u'course comment']
# [u'']
# [u'Rejected']
# [u'statisical']
# [u'good']
# [u'TV']
# [u'']
# [u'']
# [u'NCIS']
# [u'this is why']
# [u'Television']
# [u'TV']
# [u'CSI']
# [u'pre-course']
# [u'TV']
# [u'realism']
# [u'impulsive']
# [u'chantelle']
# [u'staff']
# [u'']
# [u'mhsweeney']
# [u'Episode 1 - Profiling']
# [u'sm knots']
# [u's&m knots']
# [u's&m knot']
# [u'who did it']
# [u'cardboard']
# [u'quiz']
# [u'Nancy']
# [u'elizabeth']
# [u'opportunity']
# [u'Answer']
# [u'early']
# [u'Goldwurm']
# [u'cop']
# [u'douther']
# [u'nikos']
# [u'suspect']
# [u'negi_dee']
# [u'hands']
# [u'zironid']
# [u'is this course self paced']
# [u'is this course selfpaced']
# [u'the other right']
# [u'catherinemaureenheinrichs']
# [u'THE OTHER RIGHT']
# [u'the other right']
# [u'Alizafar']
# [u'professor']
# [u'sharp']
# [u'Everyday thinking']
# [u'Think101x']
# [u'']
# [u'scien']
# [u'Think101']
# [u'statement']
# [u'greece']
# [u'nikos']
# [u'video']
# [u'video not playing']
# [u'certificate']
# [u'grade']
# [u'accomplishment']
# [u'honor']
# [u'SilverSpencer']
# [u'Marcie7']
# [u'Marcie']
# [u'interrogation']
# [u'mine']
# [u'Keerthana']
# [u'celey']
# [u'shari']
# [u'suspect']
# [u'sarahlipu']
# [u'sarahlipu']
# [u'Episode 1']
# [u'elaopg']
# [u'episode 1']
# [u'episode 1']
# [u'episode 3']
# [u'PROFILLING']
# [u'check']
# [u'submit']
# [u'certificates']
# [u'THE VERDICT']
# [u'kriti_g']
# [u'certificate']
# [u'certificates']
# [u'good wife']
# [u'guilty']
# [u'certificate']
# [u'double negatives']
# [u'agent0007']
# [u'agent 0007']
# [u'agent 007']
# [u'certification']
# [u'episode 2']
# [u'certificate']
# [u'certificate']
# [u'wig']
# [u'cert']
# [u'certifacate']
# [u'Criminal Investigative Analysis: Practitioner Perspectives']
# [u'sydney']
# [u'certificate']
# [u'rape']
# [u'certificate']
# [u'voice']
# [u'sarahlipu']
# [u'episode 4']
# [u'certificate']
# [u'diploma']
# [u'certificat']
# [u'certificate']
# [u'end']
# [u'episode 4 question 5']
# [u'interview']
# [u'coakleyboth']
# [u'both']
# [u'coakley']
# [u'weapon']
# [u'333']
# [u'Babsi']
# [u'post grades']
# [u'certificate']
# [u'real case']
# [u'honor ']
# [u'maggielipu']
# [u'cer']
# [u'cert']
# [u'certificate']
# [u'certificae']
# [u'certaf']
# [u'certafaficate']
# [u'cert']
# [u'episode 7']
# [u'episode 1']
# [u'kendoe2928']
# [u'sarah lipu']
# [u'sarah lipu']
# [u'lipu']
# [u'juror']
# [u'elaopg']
# [u'ANKemper']
# [u'Quiz']
# [u'Questions']
# [u'cotton']
# [u'jennifer']
# [u'wrongful conviction']
# [u'dianneds']
# [u'episode 1']
# [u'algebraic accessment']
# [u'acacademic assessment']
# [u'academic assessment']
# [u'quiz']
# [u'grades']
# [u'Questions']
# [u'Marina Ven']
# [u'Quiz']
# [u'Marina Vene']
# [u'course zero']
# [u'course 0']
# [u'certificate']
# [u'quiz']
# [u'certificates']
# [u'larry1964']
# [u'staff']
# [u'english']
# [u'lan']
# [u'language']
# [u'edx']
# [u'episode 8']
# [u'episode 8']
# [u'TeodoraR']
# [u' morre evidence']
# [u'episode 6']
# [u'algebraic assessment']
# [u'']
# [u'episode morre evidence']
# [u' more evidence']
# [u'did i pass']
# [u'passing grade']
# [u'algebraic assessment']
# [u'passing grade']
# [u'algebraic assessment']
# [u'episode 7']
# [u'marcqleonard']
# [u'how to get certificate']
# [u'bondage']
# [u'good samaritan']
# [u'good samaritan']
# [u'course']
# [u'female expert']
# [u'clothes']
# [u'shirt']
# [u'TeodoraR']
# [u'thank']
# [u'thank you']
# [u'certificate']
# [u'longer']
# [u'grading']
# [u'']
# [u'retake']
# [u'certificate']
# [u'BriKie']
# [u'by Staff']
# [u'coerced']
# [u'4']
# [u'coerced']
# [u'Episode 7']
# [u'kendoe2928']
# [u'kendoe2829']
# [u'elaopg']
# [u'deadline']
# [u'hoistic']
# [u'your memory']
# [u'memory']
# [u'memory of the crime']
# [u'tomg']
# [u'photofit']
# [u'who did you pick']
# [u'lineup']
# [u'What does reasonable guilt mean?']
# [u'checklist ']
# [u'save']
# [u'influenced']
# [u'thanks']
# [u'anonymous']
# [u'check']
# [u'episode 4']
# [u'recent']
# [u'certificate']
# [u'certificate']
# [u'press']
# [u'gws001']
# [u'freedom']
# [u'Inbar']
# [u'episode 4']
# [u'Certificate']
# [u'episode 1']
# [u'post I need to do yet']
# [u'kendoe2928']
# [u'gws001 ']
# [u'chaun']
# [u'chaun']
# [u"kate's approach"]
# [u'Tamara1331']
# [u'tamara1331']
# [u'fiction']
# [u'guilty til']
# [u'episode']
# [u'coerced internalised']
# [u'guilty til']
# [u'']
# [u'Maggielipu']
# [u'rape']
# [u'sarahlipu']
# [u'maggielipu']
# [u'']
# [u'non-verbal']
# [u'serums']
# [u'truth']
# [u'']
# [u'jodie']
# [u'Marina Ven']
# [u'Marina']
# [u'serum']
# [u'study group']
# [u'facebook']
# [u'transcripts']
# [u'serum']
# [u'negi_dee']
# [u'truth serum']
# [u'jillian']
# [u'jill']
# [u'jill']
# [u'jill']
# [u'ray why']
# [u'episode 4']
# [u'serum']
# [u'eye witness']
# [u'eyewitness']
# [u'episode 2']
# [u'eye witness']
# [u'episode 1']
# [u'kendoe2928']
# [u'kendoe']
# [u'eye witness']
# [u'episode 1']
# [u'episode 1']
# [u'ElaOpG']
# [u'']
# [u'italiani']
# [u'italy']
# [u'italia']
# [u'is a foil']
# [u'facial recognition issues']
# [u'interroga']
# [u'metodo']
# [u'naples']
# [u'rome']
# [u'italiano']
# [u'identifying famouse']
# [u'identifying famous faces']
# [u'half']
# [u'photo']
# [u'where']
# [u'where are you from?']
# [u'anali']
# [u'rape']
# [u'question 8']
# [u'celey']
# [u'INTERVIEW STYLES']
# [u'SarahLipu']
# [u'maggielipu']
# [u'GMH']
# [u'mike']
# [u'rape']
# [u'rape']
# [u'weapon']
# [u'']
# [u'ray']
# [u'ray why']
# [u'honor code']
# [u'negi_dee']
# [u'transcripts']
# [u'maggielipu']
# [u'maggielipu']
# [u'vita']
# [u'catherine']
# [u'Marcie']
# [u'cooperate']
# [u'Mar']
# [u'verified']
# [u'maggielipu']
# [u'sarahlipu']
# [u'Andrea']
# [u'staff']
# [u'bush']
# [u'InbarH']
# [u'transcripts']
# [u'ray']
# [u'verified']
# [u'verified']
# [u'eye witness']
# [u'maggielipu']
# [u'sarahlipu']
# [u'chrystina84']
# [u'markmoore66']
# [u'kendoe2928']
# [u'IMSirius']
# [u'IS YOUR MEMORY OF THE CRIME ACCURATE?']
# [u'ep 5']
# [u'episode 5']
# [u'Episode 3']
# [u'serums']
# [u'sidthesloth']
# [u'agent0007']
# [u'agent0007']
# [u'mia']
# [u'crow']
# [u'larry1964']
# [u'jillianH']
# [u'certificate']
# [u'jillhayes']
# [u'TV']
# [u'staff']
# [u'my thoughts']
# [u'doubt ']
# [u'gws001']
# [u'enroll']
# [u'enrolled']
# [u'how many']
# [u'dianneds']
# [u'episode 7']
# [u'jill']
# [u'progress']
# [u'neil fox']
# [u'niel fox']
# [u'certificate']
# [u'']
# [u'Failed test']
# [u'quiz week 8']
# [u'staff']
# [u'my thoughts']
# [u'my thoughts']
# [u'Episode 4']
# [u'quizz']
# [u'passed']
# [u'Australian']
# [u'Australia']
# [u'Tangen']
# [u'Think101x']
# [u'Think101']
# [u'certificate']
# [u'juror']
# [u'episiod 1']
# [u'celes']
# [u'exam']
# [u'final']
# [u'jury selection']
# [u'friend']
# [u'mark moore66']
# [u'markmoore66']
# [u'strong case']
# [u'foreperson']
# [u'episode 2']
# [u'kumar ']
# [u'kumar ']
# [u'kumar ']
# [u'dianeds']
# [u'sereis']
# [u'series']
# [u'TV']
# [u'shows']
# [u'episode 1']
# [u'hypnosis']
# [u'morcom']
# [u'ferguson']
# [u'']
# [u'certificate']
# [u'course']
# [u'CelesteLawson']
# [u'larry1964']
# [u'jurors']
# [u'staff']
# [u'staff']
# [u'Episode 3']
# [u'cultural bias']
# [u'pinned']
# [u'trial by media']
# [u'wilson']
# [u'mike brown']
# [u'like brown']
# [u'ferguson']
# [u'ferguson']
# [u'elaopg']
# [u'great']
# [u'thank']
# [u'']
# [u'to staff']
# [u'']
# [u'learn']
# [u'good']
# [u'kumar']
# [u'jodiemichelle13']
# [u'jodielane13']
# [u'episode 1 ']
# [u'']
# [u'Episode 6']
# [u'by staff']
# [u'dianneds']
# [u'dianneds']
# [u'Tarheeld']
# [u'honor']
# [u'eyewitness ']
# [u'Boyfriend']
# [u'video does not load']
# [u'episiode 1']
# [u'eyewitness ']
# [u'episode 4']
# [u'']
# [u'rolf']
# [u'Episode']
# [u'episode 2']
# [u'Wig']
# [u'bmasser']
# [u'']
# [u'gws001']
# [u'Episode 1']
# [u'Episode 1']
# [u'Episode 1']
# [u'activities']
# [u'grade']
# [u'deadline']
# [u'certificate']
# [u'policeman']
# [u'']
# [u'catalinadelatorre']
# [u'andreapetry']
# [u'AndreaPetry']
# [u'sarahlipu']
# [u'maggielipu']
# [u'episode 2']
# [u'episode 2']
# [u'discussion']
# [u'episode 2']
# [u'LINKEDIN']
# [u'certificates of completion']
# [u'pre-course']
# [u'episode 1']
# [u'eliska']
# [u'eliska']
# [u'spanish']
# [u'children']
# [u'eyewitness']
# [u'espanol']
# [u'quiz']
# [u'language']
# [u'episode 1']
# [u'eliska']
